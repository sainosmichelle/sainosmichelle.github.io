# %% [markdown]
# #1. Ejemplo de una regresión lineal simple
# Dataset temperatura promedio anual de la Nueva York
#
# El conjunto es univariado,  indica el año y la temperatura promedio
#
# Número de instancias: 124

# %% [markdown]
# # 2. Acceso a google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = r'/content/drive/Shareddrives/Data Science para Geociencias/6. Métodos de ML/6.1 Regresión lineal múltiple'
name = 'nyc_temp_1895-2018.csv'

# %% [markdown]
# #3. Importación de librerías

# %%
import numpy as ____
import matplotlib.pyplot as ____
import pandas as pd
import os
path_file = os.path.join(path,name)

# %% [markdown]
# # 4. Lectura y visualización del dataset

# %%
dataset = pd.read_csv(path_file)

dataset.columns= ['Fecha', 'Temperatura']

#ajustando las fechas
dataset.Fecha=dataset.Fecha.floordiv(100)


X = dataset.Fecha
y = dataset.Temperatura
dataset.head(10)
# Out:
#    Fecha  Temperatura
# 0   1895         34.2
# 1   1896         34.7
# 2   1897         35.5
# 3   1898         39.6
# 4   1899         36.4
# 5   1900         37.4
# 6   1901         37.0
# 7   1902         35.0
# 8   1903         35.5
# 9   1904         29.8

# %%
plt.figure(figsize=(15, 9))
plt.plot(X,y, color = '_____')
plt.title('Temperatura promedio anual NY')
plt.xlabel('Año')
plt.ylabel('Temp °C')
plt.ylim((20,50))
plt.xlim((np.min(X),np.____(X)))
plt.show()

# %% [markdown]
# #5. Diviendo el dataset en conjunto para entrenamiento y prueba

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X.values.reshape(-1,1), y.values, test_size = ____)

print(f'Dimension de los datos de entrenamiento {X_train.shape}')
print(f'Dimension de los datos de prueba {X_test._____}')
# Out:
# Dimension de los datos de entrenamiento (93, 1)
# Dimension de los datos de prueba (31, 1)

# %% [markdown]
# #6. Creación y entrenamiento de un modelo de regresión lineal simple

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

print(f'Los parámetros del modelo son: ')
print(f'{regressor.coef_} y {regressor.______}')
# Out:
# Los parámetros del modelo son:
# [0.01252345] y 13.615587694804386

# %% [markdown]
# #7. Prediciendo valores con el conjunto de prueba

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# #8. Visualización de conjunto entrenamiento

# %%
plt.figure(figsize=(15, 9))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Temp. promedio anual NY (Entrenamiento)')
plt.xlabel('Año')
plt.ylabel('Temp')
plt.ylim((10,70))
plt.show()

# %% [markdown]
# #9. Visualización del resultado (conjunto de prueba)

# %%
plt.figure(figsize=(15, 9))
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = '____')
plt.title('Temp. promedio anual NY (Prueba)')
plt.xlabel('Año')
plt.ylabel('Temp')
plt.ylim((10,70))
plt.show()

# %% [markdown]
# #10. Pedecir un valor de un dato completamente nuevo

# %%
predict = (lambda x: regressor.coef_ * x + regressor.intercept_)

print('La temp promedio anual predicha del 2020 es: ',  predict(2020))
# Out:
# La temp promedio anual predicha del 2020 es:  [38.59090695]

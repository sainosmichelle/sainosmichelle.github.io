# %% [markdown]
# ### Montando drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Importando módulos

# %%
import os
import cv2
import ____ as plt
from ____.feature import hog
from google.colab.patches import cv2_imshow

# %%
pip install mahotas

# %%
import ____

# %% [markdown]
# ## Lectura de imagen

# %%
img_path = _______
img_name = "Industrial_1825.jpg"
img_full_path = os.path.join(_____,_____)

# %%
img = cv2.imread(______, cv2.IMREAD_UNCHANGED)

# %% [markdown]
# ### Visualización

# %%
cv2_imshow(_____)

# %%
fig.set_size_inches(8,6)
plt.imshow(____, cmap='gray')
plt.title('industrial')
plt.show()

# %% [markdown]
# ### Tamaño de imagen

# %%
____.shape
# Out:
# (64, 64, 3)

# %% [markdown]
# # Descriptores de imágenes

# %%
gray = _____.cvtColor(_____, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# Visualización de imagen en grises

# %%
cv2_imshow(____)

# %% [markdown]
# ## Histograma de color

# %%
color = ('b','g','r')
for i,col in enumerate(color):
    histr = _____.calcHist([_____],[___],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.grid('on')
plt.show()

# %%
cv2.calcHist([____],[i],None,[256],[0,256]).shape

# %% [markdown]
# ## Momentos Hu

# %%
# calculo del vector de rasgos de momentos Hu
Hu = cv2._____(cv2.moments(____)).flatten()
print(Hu)

# %%
_____.shape
# Out:
# (7,)

# %% [markdown]
# ## Textura Haralick

# %%
# descriptor de rasgos: Haralick Texture
haralick = mahotas.features.haralick(_____).mean(axis=0)

# %%
______.shape
# Out:
# (13,)

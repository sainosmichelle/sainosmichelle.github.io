# %% [markdown]
# # 1. Análisis de componentes principales

# %% [markdown]
# **Objetivo:** Transofrmar el espacio de características a un espacio con componentes principales.
#
#
# **Información de las características**
# Este dataset contiene imágenes que pertenecen all dataset de EuroSat. Hay 10 folders:
# * 0 AnnualCrop
# * 1 Forest
# * 2 HerbaceousVegatation
# * 3 Highway
# * 4 Industrial
# * 5 Pasture
# * 6 PermanentCrop
# * 7 Residential
# * 8 River
# * 9 SeaLake
#
#
# **Número de instancias:** 27000

# %% [markdown]
# # 2. Autenticación a Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install -U kaleido
# !pip install plotly>=4.0.0
# !wget https://github.com/plotly/orca/releases/download/v1.2.1/orca-1.2.1-x86_64.AppImage -O /usr/local/bin/orca
# !chmod +x /usr/local/bin/orca
# !apt-get install xvfb libgtk2.0-0 libgconf-2-4

# %% [markdown]
# # 3. Importando módulos

# %%
import ____ as pd
from sklearn.decomposition import PCA
import plotly.express as ___
import plotly.io as ____
import numpy as ____
import os
from sklearn._____ import MinMaxScaler

# %% [markdown]
# # 4. Lectura de archivo

# %%
results_path = r'/content/drive/Shareddrives/Data Science para Geociencias/4. Selección de caracteristicas/Resultados'
filename = 'EUROSAT_TRAIN_FEAT.csv'
train_path = os.path.join(_____, _____)

# %%
train_df = pd.read_csv(_____)
_____.head()

# %% [markdown]
# # 5. Escalamiento

# %%
scaler = MinMaxScaler(feature_range=(___, ____))
train_df.loc[:, train_df.columns != 'label'] = scaler.______(train_df.loc[:, train_df.columns != 'label'])

# %%
_____.head()

# %% [markdown]
# # 6. PCA

# %% [markdown]
# #### a) PCA con 2 componentes

# %%
pca = PCA(n_components=2)
pc = pca.fit_transform(train_df.iloc[:,:-1])
pca_df = pd.DataFrame(data = pc
             , columns = ['PC 1', 'PC 2'])
pca_df = pd.concat([pca_df, train_df[['label']]], axis = 1)

# %% [markdown]
# Varianza acumulada alcanzada

# %%
print(np.sum(____.explained_variance_ratio_))

# %% [markdown]
# Visualización del 2D

# %%
fig = px.scatter(data_frame=____,
                    x='PC 1',
                    y='PC 2',
                    color='label',
                    color_continuous_scale=px.colors.sequential.Rainbow,
                    template='seaborn',
                    title='PCA 2D',
                    width=1000,
                    height=500)
# tight layout
fig.update_layout(margin=dict(l=0, r=0, b=0, t=25))
fig.update_traces(marker=dict(size=4),
                  selector=dict(mode='markers'))
pio.show(____)
fig.write_html("pca_2.html")
fig.write_image("pca_2.png")

# %% [markdown]
# #### b) PCA con 3 componentes *principales*

# %%
pca = PCA(n_components=3)
pc = pca.fit_transform(_____.iloc[:,:-1])
pca_df = pd.DataFrame(data = pc
             , columns = ['PC 1', 'PC 2', 'PC 3'])
pca_df = pd.concat([pca_df, train_df[['label']]], axis = 1)

# %% [markdown]
# Poder explicativo

# %%
print(np.sum(____.explained_variance_ratio_))

# %% [markdown]
# Visualización de PCA con 3 componentes

# %%
fig = px.scatter_3d(data_frame=____,
                    x='PC 1',
                    y='PC 2',
                    z='PC 3',
                    color='label',
                    color_continuous_scale=px.colors.sequential.Plasma,
                    template='seaborn',
                    title='PCA 3D EuroSat',
                    width=1300,
                    height=500)
# tight layout
fig.update_layout(margin=dict(l=0, r=0, b=0, t=25))
fig.update_traces(marker=dict(size=1),
                  selector=dict(mode='markers'))
pio.show(____)
fig.write_html("pca_3.html")
fig.write_image("pca_3.png")

# %% [markdown]
# #### c) PCA con poder explicativo del 95%

# %%
pca = PCA(0.95)
pc = pca.fit_transform(_____.iloc[:,:-1])
df_pca_train = pd.DataFrame(data = ___,
                           columns=range(pc.shape[1]))
df_pca_train = pd.concat([______, train_df[['label']]], axis = 1)

# %% [markdown]
# Poder explicativo:

# %%
print('Número de componentes principales: %s'%len(____.explained_variance_ratio_))
print('Varianza acumulada con %s componentes: %s'%(len(____.explained_variance_ratio_),np.sum(pca.______)))

# %%
_______.head()

# %% [markdown]
# Guradando el dataframe generado

# %%
df_pca_train.to_csv(os.path.join(results_path,'EUROSAT_TRAIN_PCA.csv'))
